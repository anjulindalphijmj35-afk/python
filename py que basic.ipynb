# %%
a=int(input('enter the a'))
b=int(input('enter the b'))
print(a+b)
print(a-b)
print(a*b)
# Out:
# enter the a 20
# enter the b 30
# 50
# -10
# 600

# %%
import math
a=int(input('enter the number 1'))
b=int(input('enter he number 2'))
print(math.pow(a,b))
# Out:
# enter the number 1 5
# enter he number 2 2
# 25.0

# %%
l=float(input('enter the length'))
w=float(input('enter the weight'))
h=float(input('enter the height '))
print(l*w*h)
# Out:
# enter the length 4.2
# enter the weight 5.6
# enter the height  8.2
# 192.86399999999998

# %%
r=int(input('enter the radius'))
print(2*22/7*r)
# Out:
# enter the radius 96
# 603.4285714285714

# %%
n=int(input('enter the n value'))
d=int(input('enter the d value'))
print(n/d)
print(d/n)
# Out:
# enter the n value 5
# enter the d value 20
# 0.25
# 4.0

# %%
import math
a=int(input('enter the a value'))
print(math.pow(2,2))
# Out:
# enter the a value 2
# 4.0

# %%
import math
a=int(input('enter the sqrt no'))
print(math.sqrt(25))
# Out:
# enter the sqrt no 25
# 5.0

# %%
b=int(input('enter the b'))
h=int(input('enter the h'))
print(1/2*(b/h))
# Out:
# enter the b 6
# enter the h 4
# 0.75

# %%
km=int(input('enter the km'))
print(km*0.621371)
# Out:
# enter the km 2
# 1.242742

# %%
c=int(input('enter the c'))
print(c*9/5+32)
# Out:
# enter the c 4
# 39.2

# %%
d=int(input('enter the d'))
j=int(input('enter the j'))
temp=d
d=j
j=temp
print(d)
print(j)
# Out:
# enter the d 10
# enter the j 20
# 20
# 10

# %%
a=int(input('enter the a'))
b=int(input('enter the b'))
a=a+b
b=a-b
a=a-b
print(a),print(b)
# Out:
# enter the a 10
# enter the b 20
# 20
# 10
# (None, None)

# %%
int(input('enter the a'))
int(input('enter the b'))
a=a^b
b=a^b
a=a^b
print(a),print(b)
# Out:
# enter the a 10
# enter the b 20
# 10
# 20
# (None, None)

# %%
float(input('enter the l'))
float(input('enter the w'))
print(l*w)
# Out:
# enter the l 36.1
# enter the w 45.3
# 1249.4199999999998

# %%
n=int(input('enter the n'))
print(n*(n+1)/2)
# Out:
# enter the n 9
# 45.0

# %%
a=int(input('enter the a'))
b=int(input('enter the b'))
c=int(input('enter the c'))
print(a+b+c/3)
# Out:
# enter the a 23
# enter the b 64
# enter the c 87
# 116.0

# %%
b=int(input('enter the b'))
t=5
print(b*5/100)
# Out:
# enter the b 1000
# 50.0

# %%
bp=int(input('enter the bp'))
ta=int(input('enter the ta'))
da=int(input('enter the da'))
pf=8
bp*ta/100
bp*da/100
bp*pf/100
print(bp+ta+da-pf)
# Out:
# enter the bp 20000
# enter the ta 30
# enter the da 20
# 20042

# %%
p=int(input('enter the p'))
n=int(input('enter the n'))
r=int(input('enter the r'))
print(p*n*r/100)
# Out:
# enter the p 76
# enter the n 65
# enter the r 43
# 2124.2

# %%
p=int(input('enter the p'))
r=int(input('enter the  r'))
n=int(input('enter the  n'))
t=int(input('enter the  t'))
print (p*((1+r/n)**(n*t)))
# Out:
# enter the p 10000
# enter the  r 50
# enter the  n 8
# enter the  t 7
# 1.509831103847714e+52

# %%
h=int(input('ente the h'))
f=int(input('enter the f'))
i=12
print(f*i)
# Out:
# ente the h 180
# enter the f 12
# 144

# %%
w=int(input('enter the w'))
h=int(input('enter the h'))
print(w/h*h)
# Out:
# enter the w 43
# enter the h 152
# 43.0

# %%
roll =int(input('enter your roll no'))
name=str(input('enter your name'))
tamil=int(input('enter your tamil'))
eng=int(input('enter your eng'))
maths=int(input('enter your maths'))
print(tamil+eng+maths)
print(tamil+eng+maths/3)
# Out:
# enter your roll no 4320
# enter your name jas
# enter your tamil 94
# enter your eng 70
# enter your maths 96
# 260
# 196.0
