# %%
n=int(input())
count=0
while n!=0:
    n=n//10
    count=count+1
print(count)
# Out:
#  5431
# 4

# %%
n=int(input())
sum=0
while n!=0:
    t=n%10
    sum=sum+t
    n=n//10
print(sum)
# Out:
#  4456
# 19

# %%
n=int(input())
sum=1
while n!=0:
    t=n%10
    sum=sum*t
    n=n//10
print(sum)
# Out:
#  345
# 60

# %%
n=int(input())
count=0
while n!=0:
    n=n//10
    count=count+1
print(count)
if(count%2==0):
    print('even')
else:
    print('odd')
# Out:
#  344467
# 6
# even

# %%
n=int(input())
sum=0
while n!=0:
    t=n%10
    sum=sum+t
    n=n//10
print(sum)
# Out:
#  275
# 14

# %%
n=int(input())
pos=0
oddsum=0
evensum=0
while n!=0:
    t=n%10
    if(pos%2==0):
       evensum=evensum+t
    else:
       oddsum=oddsum+t
    n=n//10
    pos=pos+1
print(oddsum)
print(evensum)
# Out:
#  29876
# 16
# 16

# %%
n=int(input())
count=0
evencount=0
oddcount=0
while n!=0:
    if(count %2==0):
        evencount=evencount+1
    else:
        oddcount=oddcount+1
    n=n//10
    count=count+1
print(evencount)
print(oddcount)
# Out:
#  23456789
# 4
# 4

# %%
n=int(input())
m=0
evensum=0
oddsum=0
while n!=0:
    t=n%10
    if(m % 2==0):
        evensum=evensum+t
    else:
        oddsum=oddsum+t
    n=n//10
    m=m+1
print(evensum)
print(oddsum)
# Out:
#  3456789
# 24
# 18

# %%
n=int(input())
while n>=9:
    n=n//10
print(n)
# Out:
#  45678
# 4

# %%
n=int(input())
n=n%10
print(n)
# Out:
#  9876543
# 3

# %%
n=int(input())
max=0
while n!=0:
    t=n%10
    if(t>max):
        max=t
    n=n//10
print(max)
# Out:
#  8765
# 8

# %%
n=int(input())
maxpos=0
pos=1
max=0
while n!=0:
    t=n%10
    if(t>max):
        max=t
        maxpos=pos
    n=n//10
    pos=pos*10
print(maxpos)
# Out:
#  567
# 1

# %%
n=int(input())
mini=9
while n!=0:
    t=n%10
    if(t<mini):
        mini=t
    n=n//10
print(mini)
# Out:
#  87
# 7

# %%
n=int(input())
minipos=0
pos=1
mini=9
while n!=0:
    t=n%10
    if(t<mini):
        mini=t
        minipos=pos
    n=n//10
    pos=pos*10
print(minipos)
# Out:
#  23456
# 10000

# %%
n=int(input())
reverse=0
count=0
while n!=0:
    t=n%10
    if(reverse*10+t):
         n=n//10
    count=count+1
print(count)
# Out:
#  1234
# 4
