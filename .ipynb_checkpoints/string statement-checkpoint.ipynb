# %%
#string statement
'Anjulin dalphi'
# Out:
# 'Anjulin dalphi'

# %%
#special characters in string
'@#$%'
# Out:
# '@#$%'

# %%
#print the string
print('hello')
# Out:
# hello

# %%
we can bind or assign a string to another variable

# %%
#assign string to variable
name='Anjulin dalphi'
print(name)
# Out:
# Anjulin dalphi

# %%
myname=name
print(id(myname))
print(id(name))
# Out:
# 1848855619248
# 1848855619248

# %%
#indexing
#print the first element in the  string
print(name[0])
print(name[6])
print(name[7])
# Out:
# A
# n

# %%
#string pooling
val='anand'
val2='anand'
print(id(val),id(val2))
va1[2]='A'
print(val[2])
# Out:
# 1848859920880 1848859920880
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 5
#       3 val2='anand'
#       4 print(id(val),id(val2))
# ----> 5 va1[2]='A'
#       6 print(val[2])
#
# NameError: name 'va1' is not defined

# %%
#print the element on idex 6 in the string
print(name[6])
# Out:
# n

# %%
#print the element on the 13th index in the string
print(name[11])
# Out:
# p

# %%
#negative string
#print the last element in the string
#Anjulin dalphi
print(name[-13])
# Out:
# n

# %%
#print the first element in string
print(name[-13])
#find the length  of string
len(name)
# Out:
# n
# 14

# %%
#slicing
#take the slice on variable name with only index 0 to index 3
name[0:4]
# Out:
# 'Anju'

# %%
#take the slice on variable name with only index 5 to intex 12
name[5:14]
# Out:
# 'in dalphi'

# %%
name[:8]
# Out:
# 'Anjulin '

# %%
name[8:]
# Out:
# 'dalphi'

# %%
name[2:8]
# Out:
# 'julin '

# %%
print(name[5:-1])
# Out:
# in dalph

# %%
print(name[-5:2])

# %%
#stride
#get every  second element. the element in index 1,3,5... sequence[start:stop:step].
#Anjulin dalphi
name[::2]
# Out:
# 'Ajlndlh'

# %%
#we can also incorporate slicing with the stride.In this case,we select the first five elements and then use the stride
#get evey second element nn the rang from index 0 to index 4
name[0:5:2]
# Out:
# 'Ajl'

# %%
#concatenate  strings
#concatenate two strings
statement=name+'!'
statement
#print the string for 3 times
#3*'ravi'
'ravi'*3
# Out:
# 'raviraviravi'

# %%
#escape sequences
#new line escape sequences
print('hello\nwelcome to trichy')
# Out:
# hello
# welcome to trichy

# %%
#tap escape sequence
print('hello\welcome to trichy')
# Out:
# hello\welcome to trichy

# %%
#include back slash in string
print('hello\\welcome to trichy')
# Out:
# hello\welcome to trichy

# %%
#r will tell python that string will be display as raw string
print(r'hello\nwelcome to trichy')
# Out:
# hello\nwelcome to trichy

# %%
#string manipulaion operations
#converting al the characters in string to upper casse
a='hello welcome to trichy'
print('before upper:',a)
b=a.upper()
print('afer upper:',b)
print(b.lower())
# Out:
# before upper: hello welcome to trichy
# afer upper: HELLO WELCOME TO TRICHY
# hello welcome to trichy

# %%
#replace the old substring with the new target substring is the segment has been found in the string
a='hello welcome to trichy'
b=a.replace('trichy','chennai')
print(b)
# Out:
# hello welcome to chennai

# %%
name='anand kumar'
print(name.find('d'))
# Out:
# 4

# %%
name.index('a',3)
# Out:
# 9

# %%
name.count('a')
# Out:
# 3

# %%
name=input('')
unique_list=[]
for char in name.lower():
    if char not in unique_list:
        unique_list.append(char)

print(unique_list)
# Out:
#  anandkumar
# ['a', 'n', 'd', 'k', 'u', 'm', 'r']
