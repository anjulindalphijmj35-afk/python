# %%
print('hello')
# Out:
# hello

# %%
print('this will be printed')
print('this will cause an error')
print('10.5')
print('this will not be printed')
# Out:
# this will be printed
# this will cause an error
# 10.5
# this will not be printed

# %%
#top right corner of this notebook

#check the python version
import sys
print(sys. version)
# Out:
# 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]

# %%
print('hello print')# print print
# Out:
# hello print

# %%
#print('welcome')
print('trichy')
# Out:
# trichy

# %%
A1=1
print(A1)
# Out:
# 1

# %%
myage=33
vole_eligibility=18
A=20
print(A)
# Out:
# 20

# %%
age1=18
age=19
my_age=18
print(my_age)
print(age1)
# Out:
# 18
# 18

# %%
age1=20
Age=18
print(age1)
# Out:
# 20

# %%
print('hello')
a='Hello'
print(a)
print(id(a))
# Out:
# hello
# Hello
# 1400650627520

# %%
yyx='hello'
print(id(yyx))
s='hello'
print(id(s))
# Out:
# 1400605820368
# 1400605820368

# %%
s2='Hello'
print(id(s2))
# Out:
# 1400650627520

# %%
s1='Hello'
s2='hello'
s3='hello'
s4='hel'+'lo'# concat
print(id(s1))# memory address of s1
print(id(s2))# memory address of s2
print(id(s3))# memory address of s3
print(id(s4))# memory address of s4
# Out:
# 1400650627520
# 1400605820368
# 1400605820368
# 1400605820368

# %%
x=10
y=10
print(id(x))
print(id(y))
print(id(x),id(y))
# Out:
# 140704939947208
# 140704939947208
# 140704939947208 140704939947208

# %%
print('Hello,python!')
# Out:
# Hello,python!

# %%
# Try to see built in error message

'hello'
'Hello, python!'
'welcome'
'trichy'
# Out:
# 'trichy'

# %% [markdown]
# TYPES OF OBJECTS IN PYTHON
#
# INTEGER
# FLOAT
# STRING
# BOOLEAM

# %%
a=10
type(a)
# Out:
# int

# %%
# integer
type(11)
# Out:
# int

# %%
#float
type(2.14)
# Out:
# float

# %%
#string
'welcome'
'hello, python1011'
# Out:
# 'hello, python1011'

# %%
# type of 12
type('11')
# Out:
# str

# %%
type(2.14)
# Out:
# float

# %%
type('Hello')
# Out:
# str

# %%
type (False)
# Out:
# bool

# %%
# print the type of-1

print(type(-1))
print(type(4))
print(type(0))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
a=10
b=11
print(a,b)

# %%
print(id(a))
print(id(b))
# Out:
# 140704939947208
# 140704939947208

# %%
type(3.0)# Notice that 3 is an int, and 3.0 is a float

# %%
type (0.56)
# Out:
# float

# %%
type (0.5)
# Out:
# float

# %%
# system swttings about float type.
import sys
sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
a=10.11000000
b=10.11000001
print(id(a),id(b))
# Out:
# 1400629851728 1400661401168

# %%
c= 0.1+0.1+0.1
print(c)
# Out:
# 0.30000000000000004

# %%
a=.1
b=.1
c=.1
a+b+c
# Out:
# 0.30000000000000004

# %%
print(.1+.1+.1)
# Out:
# 0.30000000000000004

# %%
a=0.1
b=0.3
c=a+a+a-b
print(c)
# Out:
# 5.551115123125783e-17

# %%
a=Decimal('0.1')
b=Decimal('0.3')
c=a+a+a-b
print(type(c))
print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 a=Decimal('0.1')
#       2 b=Decimal('0.3')
#       3 c=a+a+a-b
#
# NameError: name 'Decimal' is not defined

# %%
print('the result is given number:',c)
# Out:
# the result is given number: 5.551115123125783e-17

# %%
print(f'the result is{c}')
# Out:
# the result is5.551115123125783e-17

# %%
print('the resut is {c}')
# Out:
# the resut is {c}

# %%
print('the result is '+ c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 print('the result is '+ c)
#
# TypeError: can only concatenate str (not "float") to str

# %%
print('the result is'+str())
# Out:
# the result is

# %%
'1'+'s'
# Out:
# '1s'

# %%
c=2+3j
print(c)
# Out:
# (2+3j)

# %%
d=3+5j
print(c+d)
# Out:
# (5+8j)

# %%
x=5
type(x)
# Out:
# int

# %%
# convert 5 to a float
float(x)
# Out:
# 5.0

# %%
v='flase'
print(type(v))
# Out:
# <class 'str'>

# %%
type(bool(v))
# Out:
# bool

# %%
t='ravi'
bool(t)
# Out:
# True

# %%
y=17
print(float(y))
print(y)
print(type(y))
# Out:
# 17.0
# 17
# <class 'int'>

# %%
type(float(x))
# Out:
# float

# %%
#casting 1.1to integer will result in loss of information
int(145.9087)
# Out:
# 145

# %%
#convert a string into an integer
type(int('1'))
# Out:
# int

# %%
x=5
y=float(x)
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'float'>

# %%
# convert the string '1.2'into a float
float('1.2')
# Out:
# 1.2

# %%
value='ravi'
print(int(value))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 2
#       1 value='ravi'
# ----> 2 print(int(value))
#
# ValueError: invalid literal for int() with base 10: 'ravi'

# %%
#convert an integer to a string
x=5
print(str(x))
type(x)
# Out:
# 5
# int

# %%
#convert a float to a string
print(str(1.2))
# Out:
# 1.2

# %%
c=10
print('result'+c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 2
#       1 c=10
# ----> 2 print('result'+c)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print('result is'+str(c))
print(type(c))
# Out:
# result is10
# <class 'int'>

# %%
c=10
d=20
e=c+d
print('addition of two number is'+str(e))
print('addition of two number is'+str(c+d))
# Out:
# addition of two number is30
# addition of two number is30

# %%
bool('ravi')
# Out:
# True

# %%
# value true
True
False
# Out:
# False

# %%
#type of True
type(True)
# Out:
# bool

# %%
# convert True to int
int('True')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[114], line 2
#       1 # convert True to int
# ----> 2 int('True')
#
# ValueError: invalid literal for int() with base 10: 'True'

# %%
int(True)
# Out:
# 1

# %%
# convert 1 to boolean
bool (1)
# Out:
# True

# %%
# convert true to float
float (True)
# Out:
# 1.0

# %%
x=10
y=2.3
z=True
n=None
s=''
type(x),type(y),type(z),type(n),type(s)

# %%
pi='3.14'
type(float (pi))
# Out:
# float

# %%
# syntex error

print('Hello,world!')
# Out:
# Hello,world!

# %%
#runtime error

x=10
y=2
print(x/y)
# Out:
# 5.0

# %%
#logical error

debit=500
credit=1000
balance=debit-credit # logical error balance

# %%
# type error

x=10
y='ravi'
print (x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 5
#       3 x=10
#       4 y='ravi'
# ----> 5 print (x+y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#value error
int('abs')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 #value error
# ----> 2 int('abs')
#
# ValueError: invalid literal for int() with base 10: 'abs'

# %%
age=10
age=input('enter your age')
print(f'your age is {age}')
# Out:
# enter your age 23
# your age is 23

# %%
no1=input('enter number1')
no2=input('enter number2')
print(no1+no2)
print(type(no1))
print(type(no2))
# Out:
# enter number1 10
# enter number2 20
# 1020
# <class 'str'>
# <class 'str'>

# %%
name=input('enter your name')
print(name)
type(name)
# Out:
# enter your name ravi
# ravi
# str

# %%
age=int(input('enter your age'))
age1=int(input('enter your age'))
# Out:
# enter your age 23
# enter your age 23

# %%
name=input('enter your name')
age=int(input('enter your age'))
height=float(input('ener your height'))
married status=bool(input('are u married'?))
print('Hi'+name+'you are at'+str(age)+'your height is'+str(height)+'your status is'+str(married status)
print(f'hi{name}you are at {age}your height is {height}your status is {married}
# Out:
#   Cell In[59], line 4
#     married status=bool(input('are u married'?))
#             ^
# SyntaxError: invalid syntax

# %%
10//2
# Out:
# 5
