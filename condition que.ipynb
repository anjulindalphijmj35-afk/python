# %%
n=int(input('enter the n'))
if(n>0):
    print('positive')
elif(n<0):
    print('negative')
else:
    print('invalid number')
# Out:
# enter the n -5
# negative

# %%
n1=int(input('enter the n1'))
n2=int(input('enter the n2'))
if(n1==n2):
    print('equal')
elif(n1!=n2):
    print('not equal')
# Out:
# enter the n1 44
# enter the n2 46
# not equal

# %%
f1=float(input('enter the f1'))
f2=float(input('enter the f2'))
if(f1==f2):
    print('equal')
elif(f1!=f2):
    print('not equal')
# Out:
# enter the f1 4
# enter the f2 5
# not equal

# %%
n=int(input('enter the n'))
if(n%2==0):
    print('even')
elif(n%2!=0):
    print('odd')
# Out:
# enter the n 5
# odd

# %%
y=int(input('enter the y'))
if(y%4==0 and y%100!=0):
    print('leaf year')
elif(y%400==0):
    print('leaf year')
else:
    print('not invalid year')
# Out:
# enter the y 2016
# leaf year

# %%
n=int(input('enter the n'))
if(n>=18):
    print('can vote')
else:
    print('cannot vote')
# Out:
# enter the n 18
# can vote

# %%
t=int(input('enter the t'))
if(t>100):
    print('tall')
elif(t>60 and t<70):
    print('medium')
else:
    print('sort')
# Out:
# enter the t 35
# sort

# %%
l1=int(input('enter the l1'))
l2=int(input('enter the l2'))
l3=int(input('enter the l3'))
if(l1>l2 and l1>l3):
    print('large number',l1)
elif(l2>l1 and  l2>l3):
    print('large number',l2)
elif(l3>l1 and l3>l1):
    print('large number',l3)
else:
    print('invalid number')
# Out:
# enter the l1 5
# enter the l2 9
# enter the l3 10
# large number 10

# %%
s1=int(input('enter the s1'))
s2=int(input('enter the s2'))
s3=int(input('enter the s3'))
if(s1<s2 and s1<s3):
    print('small number',s1)
elif(s2<s1 and  s2<s3):
    print('small number',s2)
elif(s3<s1 and s3<s1):
    print('small number',s3)
else:
    print('invalid number')
# Out:
# enter the s1 65
# enter the s2 87
# enter the s3 43
# small number 43

# %%
l1=int(input('enter the l1'))
l2=int(input('enter the l2'))
l3=int(input('enter the l3'))
l4=int(input('enter the l4'))
if(l1>l2 and l1>l3 and l1>l4):
    print('large no',l1)
elif(l2>l1 and l2>l3 and l2>l4):
    print('large no',l2)
elif(l3>l1 and l3>l2 and l3>l4):
    print('large no',l3)
elif(l4>l1 and l4>l2 and l4>l3):
    print('large no',l4)
# Out:
# enter the l1 65
# enter the l2 65
# enter the l3 23
# enter the l4 98
# large no 98

# %%
a=int(input('enter the a'))
b=int(input('enter the b'))
c=int(input('enter the c'))
abdiff=abs(a-b)
bcdiff=abs(b-c)
acdiff=abs(a-c)
minimum=min(abdiff,bcdiff,acdiff)
if(abdiff==minimum):
    print('a&b closer')
if(bcdiff==minimum):
    print('b&c closer')
if(acdiff==minimum):
    print('a&c closer')
# Out:
# enter the a 5
# enter the b 15
# enter the c 28
# a&b closer

# %%
a=int(input('enter the a'))
b=int(input('enter the b'))
c=int(input('enter the c'))
abdiff=abs(a-b)
bcdiff=abs(b-c)
acdiff=abs(a-c)
maximum=max(abdiff,bcdiff,acdiff)
if(abdiff==maximum):
    print('a&b farther')
if(bcdiff==maximum):
    print('b&c farther')
if(acdiff==maximum):
    print('a&c farther')
# Out:
# enter the a 5
# enter the b 15
# enter the c 27
# a&c farther

# %%
a=int(input('enter the a'))
b=int(input('enter the b'))
c=int(input('enter the c'))
abdiff=abs(a-b)
bcdiff=abs(b-c)
acdiff=abs(a-c)
minimum=min(abdiff,bcdiff,acdiff)
if(abdiff==minimum):
    print('a&b closer')
if(bcdiff==minimum):
    print('b&c closer')
if(acdiff==minimum):
    print('a&c closer')
maximum=max(abdiff,bcdiff,acdiff)
if(abdiff==maximum):
    print('a&b farther')
if(bcdiff==maximum):
    print('b&c farther')
if(acdiff==maximum):
    print('a&c farther')
# Out:
# enter the a 10
# enter the b 20
# enter the c 60
# a&b closer
# a&c farther

# %%
a=int(input('enter the a'))
b=int(input('ener the b'))
c=int(input('enter the c'))
if(a+b+c==180):
    print('can form triangle')
else:
    print('can not form triangle')
# Out:
# enter the a 80
# ener the b 40
# enter the c 60
# can form triangle

# %%
x=int(input('enter the x'))
y=int(input('enter the y'))
if(x>0 and y>0):
    print('1st quadrant')
elif(x>0 and y<0):
    print('2nd quadrant')
elif(x<0 and y<0):
    print('3rd quadrant')
elif(x<0 and y>0):
    print('4th quadrant')
elif(x==0):
    print('5th quadrant')
elif(y==0):
    print('6th quadrant')
elif(x,y):
    print('7th quadrant')
# Out:
# enter the x 0
# enter the y 0
# 5th quadrant

# %%
n=str(input('enter the n'))
if(n=='a' or n=='e' or n=='i' or n=='o'):
    print('vowel')
else:
    print('consonant')
# Out:
# enter the n e
# vowel

# %%
month=str(input('enter the month'))
if month in ('jan','mar','may','july','aug','oct','dec'):
    print('31')
elif month in ('april','june','sep','nov'):
    print('30')
elif month in ('feb'):
    print('28')
else:
    print('invalid month')
# Out:
# enter the month jan
# 31

# %%
num = int(input('enter the num:'))
if(num%7 == 1):
    print('monday')
elif(num%7 == 2):
    print('tuesday')
elif(num%7 == 3):
    print('wednesday')
elif(num%7 == 4):
    print('thursday')
elif(num%7 == 5):
    print('friday')
elif(num%7 == 6):
    print('saturday')
elif(num%7 == 0):
    print('sunday')
else:
    print('invalid day')
# Out:
# enter the num: 30
# tuesday

# %%
a=int(input('enter the a'))
b=int(input('enter the b'))
c=int(input('enter the c'))
if(a==b and b==c):
    print('equailateral')
elif(a!=b and b!=c):
    print('isosceles')
elif(a==b and b!=c):
    print('scalene')
# Out:
# enter the a 10
# enter the b 10
# enter the c 10
# equailateral

# %%
row=int(input('enter the row'))
column=int(input('enter the column'))
if((row+column) %2==0):
    print('black')
elif((row+column) %2!=0):
    print('white')
# Out:
# enter the row 2
# enter the column 3
# white

# %%
mark=int(input('enter the mark'))
if(mark>90):
    print('A')
elif(mark>80):
    print('B')
elif(mark>60):
    print('C')
elif(mark>50):
    print('D')
elif(mark<50):
    print('F')
else:
    print('invalid mark')
# Out:
# enter the mark 90
# B

# %%
purchase=int(input('enter the purchase'))
sales=int(input('enter the sales'))
if(purchase<sales):
    print('profit')
elif(purchase>sales):
    print('loss')
# Out:
# enter the purchase 10000
# enter the sales 5000
# loss

# %%
print('1.addition')
print('2.subtraction')
print('3.multiplication')
print('4.division')
print('5.modulo division')
n1=int(input('enter the n1'))
n2=int(input('enter the n2'))
if n==1:
    print(n1+n2)
elif n==2:
    print(n1-n2)
elif n==3:
    print(n1*n2)
elif n==4:
    print(n1/n2)
elif n==5:
    print(n1%n2)
# Out:
# 1.addition
# 2.subtraction
# 3.multiplication
# 4.division
# 5.modulo division
# enter the n1 34
# enter the n2 65
# 34

# %%
import random
print('1.rock')
print('2.paper')
print('3.scissors')
user=int(input('enter the user'))
com=random.randint (1,3)
if(user==1 and com==3):
    print('you win')
elif(com==1 and user==2):
    print('you win')
elif(com==2 and user==3):
    print('you win')
elif(com==user):
    print('traw')
else:
    print('system win')
# Out:
# 1.rock
# 2.paper
# 3.scissors
# enter the user 3
# you win

# %%
num = int(input('enter the num'))
if(num <10):
    print('not manju birthday')
elif(num == 10):
    print('happy birthday manju')
else:
    print('invalid number')
# Out:
# enter the num 10
# happy birthday manju
